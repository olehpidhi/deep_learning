# %%
from Train import *
from NeuralNet import tanh_f

input, labels = get_data()

# %% [markdown]
# ## Softmax

# %%
for rate in [0.01, 0.001, 0.0001]:
    for batch in [10, 15 , 20]:
        print("Softmax, learning rate={}, batch size={}".format(rate, batch))
        model = build_model(learning_rate=rate)
        trainer = Trainer(input, labels, batch, 10)
        train_loss, validation_loss, train_accuracies, validation_accuracies = trainer.fit(model=model)
        trainer.plot_model(train_loss, validation_loss, train_accuracies, validation_accuracies)
# Out:
# Softmax, learning rate=0.01, batch size=10
# Softmax, learning rate=0.01, batch size=15
# Softmax, learning rate=0.01, batch size=20
# Softmax, learning rate=0.001, batch size=10
# Softmax, learning rate=0.001, batch size=15
# Softmax, learning rate=0.001, batch size=20
# Softmax, learning rate=0.0001, batch size=10
# Softmax, learning rate=0.0001, batch size=15
# Softmax, learning rate=0.0001, batch size=20

# %%
print("tahnh, learning rate={}, batch size={}".format(rate, batch))
model = build_model(learning_rate=0.0001, last_activation=tanh_f)
trainer = Trainer(input, labels, 20, 10)
train_loss, validation_loss, train_accuracies, validation_accuracies = trainer.fit(model=model)
trainer.plot_model(train_loss, validation_loss, train_accuracies, validation_accuracies)
# Out:
# tahnh, learning rate=0.0001, batch size=20
